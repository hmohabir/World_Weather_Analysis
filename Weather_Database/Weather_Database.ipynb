# %%
#Dependencies
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import gmaps
import json
import requests
from datetime import datetime

#Import Weather API Key
from config import weather_api_key

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=23b3d74cf147bf88ce569ade6185f448

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Obtaining the Lat and long in a list
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
from citipy import citipy

# %%
# List for holding lat_lngs and cities
# lat_lngs = []
cities = []

# %%
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 780

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Obtain JSON view and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_current_description = city_weather["weather"]
        city_current_description = city_current_description[0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | aklavik
# Processing Record 4 of Set 1 | college
# Processing Record 5 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 1 | tarata
# Processing Record 7 of Set 1 | arraial do cabo
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | ribeira grande
# Processing Record 11 of Set 1 | sarandi
# Processing Record 12 of Set 1 | ponta do sol
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | cabo san lucas
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | padang
# Processing Record 20 of Set 1 | thompson
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 1 | saskylakh
# Processing Record 24 of Set 1 | victoria
# Processing Record 25 of Set 1 | kudahuvadhoo
# Processing Record 26 of Set 1 | saint george
# Processing Record 27 of Set 1 | maxixe
# Processing Record 28 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 29 of Set 1 | sao joao da barra
# Processing Record 30 of Set 1 | north bend
# Processing Record 31 of Set 1 | ikongo
# Processing Record 32 of Set 1 | buala
# Processing Record 33 of Set 1 | huambo
# Processing Record 34 of Set 1 | kruisfontein
# Processing Record 35 of Set 1 | biltine
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | upernavik
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | poum
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | iqaluit
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | vao
# Processing Record 44 of Set 1 | tuktoyaktuk
# Processing Record 45 of Set 1 | calvinia
# Processing Record 46 of Set 1 | guaruja
# Processing Record 47 of Set 1 | port lincoln
# Processing Record 48 of Set 1 | deputatskiy
# Processing Record 49 of Set 1 | tiksi
# Processing Record 50 of Set 1 | kahului
# Processing Record 1 of Set 2 | margate
# Processing Record 2 of Set 2 | ostrovnoy
# Processing Record 3 of Set 2 | bambous virieux
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | roald
# Processing Record 6 of Set 2 | hudiksvall
# Processing Record 7 of Set 2 | badaojiang
# City not found. Skipping...
# Processing Record 8 of Set 2 | carballo
# Processing Record 9 of Set 2 | plettenberg bay
# Processing Record 10 of Set 2 | tahe
# Processing Record 11 of Set 2 | san patricio
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | yerbogachen
# Processing Record 14 of Set 2 | rio gallegos
# Processing Record 15 of Set 2 | pyaozerskiy
# Processing Record 16 of Set 2 | satana
# Processing Record 17 of Set 2 | muli
# Processing Record 18 of Set 2 | yanam
# Processing Record 19 of Set 2 | labuhan
# Processing Record 20 of Set 2 | guabito
# Processing Record 21 of Set 2 | morros
# Processing Record 22 of Set 2 | mount gambier
# Processing Record 23 of Set 2 | te anau
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | chuy
# Processing Record 26 of Set 2 | haines junction
# Processing Record 27 of Set 2 | new norfolk
# Processing Record 28 of Set 2 | ewa beach
# Processing Record 29 of Set 2 | kissamos
# Processing Record 30 of Set 2 | beringovskiy
# Processing Record 31 of Set 2 | avarua
# Processing Record 32 of Set 2 | kalakamati
# Processing Record 33 of Set 2 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 34 of Set 2 | progreso
# Processing Record 35 of Set 2 | vaini
# Processing Record 36 of Set 2 | klaksvik
# Processing Record 37 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 2 | yumen
# Processing Record 39 of Set 2 | west bay
# Processing Record 40 of Set 2 | puerto ayora
# Processing Record 41 of Set 2 | evensk
# Processing Record 42 of Set 2 | garowe
# Processing Record 43 of Set 2 | nikolskoye
# Processing Record 44 of Set 2 | tommot
# Processing Record 45 of Set 2 | sorland
# Processing Record 46 of Set 2 | bilma
# Processing Record 47 of Set 2 | kodiak
# Processing Record 48 of Set 2 | punta alta
# Processing Record 49 of Set 2 | vila velha
# Processing Record 50 of Set 2 | ancud
# Processing Record 1 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 3 | riyadh
# Processing Record 3 of Set 3 | coihaique
# Processing Record 4 of Set 3 | kaitangata
# Processing Record 5 of Set 3 | east london
# Processing Record 6 of Set 3 | saldanha
# Processing Record 7 of Set 3 | pecos
# Processing Record 8 of Set 3 | viedma
# Processing Record 9 of Set 3 | christchurch
# Processing Record 10 of Set 3 | kavieng
# Processing Record 11 of Set 3 | souillac
# Processing Record 12 of Set 3 | cruzeiro do sul
# Processing Record 13 of Set 3 | qaanaaq
# Processing Record 14 of Set 3 | tongren
# Processing Record 15 of Set 3 | campos sales
# Processing Record 16 of Set 3 | mayo
# Processing Record 17 of Set 3 | great yarmouth
# Processing Record 18 of Set 3 | hillerod
# Processing Record 19 of Set 3 | gardner
# Processing Record 20 of Set 3 | vanavara
# Processing Record 21 of Set 3 | hofn
# Processing Record 22 of Set 3 | skjervoy
# Processing Record 23 of Set 3 | alghero
# Processing Record 24 of Set 3 | beisfjord
# Processing Record 25 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 3 | praia
# Processing Record 27 of Set 3 | codrington
# Processing Record 28 of Set 3 | klyuchi
# Processing Record 29 of Set 3 | vostok
# Processing Record 30 of Set 3 | berdigestyakh
# Processing Record 31 of Set 3 | dikson
# Processing Record 32 of Set 3 | laguna
# Processing Record 33 of Set 3 | matagami
# Processing Record 34 of Set 3 | thoen
# Processing Record 35 of Set 3 | savannah bight
# Processing Record 36 of Set 3 | northam
# Processing Record 37 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 38 of Set 3 | yizheng
# Processing Record 39 of Set 3 | necochea
# Processing Record 40 of Set 3 | madras
# Processing Record 41 of Set 3 | bayir
# Processing Record 42 of Set 3 | atambua
# Processing Record 43 of Set 3 | jamestown
# Processing Record 44 of Set 3 | tulun
# Processing Record 45 of Set 3 | kyren
# Processing Record 46 of Set 3 | mincivan
# Processing Record 47 of Set 3 | busselton
# Processing Record 48 of Set 3 | butaritari
# Processing Record 49 of Set 3 | ecija
# Processing Record 50 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 4 | teknaf
# Processing Record 2 of Set 4 | cayenne
# Processing Record 3 of Set 4 | uyemskiy
# Processing Record 4 of Set 4 | mar del plata
# Processing Record 5 of Set 4 | payo
# Processing Record 6 of Set 4 | hamburg
# Processing Record 7 of Set 4 | port moresby
# Processing Record 8 of Set 4 | bluff
# Processing Record 9 of Set 4 | bichena
# Processing Record 10 of Set 4 | antofagasta
# Processing Record 11 of Set 4 | mazatlan
# Processing Record 12 of Set 4 | kiboga
# Processing Record 13 of Set 4 | comodoro rivadavia
# Processing Record 14 of Set 4 | lubango
# Processing Record 15 of Set 4 | jumla
# Processing Record 16 of Set 4 | asau
# Processing Record 17 of Set 4 | dali
# Processing Record 18 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 4 | bhiwani
# Processing Record 20 of Set 4 | griffith
# Processing Record 21 of Set 4 | smithers
# Processing Record 22 of Set 4 | georgetown
# Processing Record 23 of Set 4 | gigmoto
# Processing Record 24 of Set 4 | santiago del estero
# Processing Record 25 of Set 4 | bukachacha
# Processing Record 26 of Set 4 | provideniya
# Processing Record 27 of Set 4 | ineu
# Processing Record 28 of Set 4 | santa lucia
# Processing Record 29 of Set 4 | grand gaube
# Processing Record 30 of Set 4 | sao filipe
# Processing Record 31 of Set 4 | aksu
# Processing Record 32 of Set 4 | katsuura
# Processing Record 33 of Set 4 | namibe
# Processing Record 34 of Set 4 | talnakh
# Processing Record 35 of Set 4 | tateyama
# Processing Record 36 of Set 4 | hamilton
# Processing Record 37 of Set 4 | verkhoyansk
# Processing Record 38 of Set 4 | otta
# Processing Record 39 of Set 4 | port hardy
# Processing Record 40 of Set 4 | key west
# Processing Record 41 of Set 4 | bilibino
# Processing Record 42 of Set 4 | thyboron
# Processing Record 43 of Set 4 | lorengau
# Processing Record 44 of Set 4 | hervey bay
# Processing Record 45 of Set 4 | flinders
# Processing Record 46 of Set 4 | cairns
# Processing Record 47 of Set 4 | sault sainte marie
# Processing Record 48 of Set 4 | proletariy
# Processing Record 49 of Set 4 | yinchuan
# Processing Record 50 of Set 4 | khatanga
# Processing Record 1 of Set 5 | kushiro
# Processing Record 2 of Set 5 | guerrero negro
# Processing Record 3 of Set 5 | chipata
# Processing Record 4 of Set 5 | hammerfest
# Processing Record 5 of Set 5 | carnarvon
# Processing Record 6 of Set 5 | ulagan
# Processing Record 7 of Set 5 | bethel
# Processing Record 8 of Set 5 | esperance
# Processing Record 9 of Set 5 | valparaiso
# Processing Record 10 of Set 5 | bridgetown
# Processing Record 11 of Set 5 | inhambane
# Processing Record 12 of Set 5 | verkhniy avzyan
# Processing Record 13 of Set 5 | bengkulu
# Processing Record 14 of Set 5 | ardakan
# Processing Record 15 of Set 5 | bathsheba
# Processing Record 16 of Set 5 | burkhala
# City not found. Skipping...
# Processing Record 17 of Set 5 | acapulco
# Processing Record 18 of Set 5 | muros
# Processing Record 19 of Set 5 | magdagachi
# Processing Record 20 of Set 5 | lusambo
# Processing Record 21 of Set 5 | tilichiki
# Processing Record 22 of Set 5 | kanniyakumari
# Processing Record 23 of Set 5 | ilulissat
# Processing Record 24 of Set 5 | lazaro cardenas
# Processing Record 25 of Set 5 | henties bay
# Processing Record 26 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 5 | kihei
# Processing Record 28 of Set 5 | axim
# Processing Record 29 of Set 5 | anapolis
# Processing Record 30 of Set 5 | pinega
# Processing Record 31 of Set 5 | saint-joseph
# Processing Record 32 of Set 5 | road town
# Processing Record 33 of Set 5 | chumikan
# Processing Record 34 of Set 5 | san ignacio
# Processing Record 35 of Set 5 | koluszki
# Processing Record 36 of Set 5 | yuma
# Processing Record 37 of Set 5 | kirakira
# Processing Record 38 of Set 5 | uige
# Processing Record 39 of Set 5 | ilmatsalu
# Processing Record 40 of Set 5 | onega
# Processing Record 41 of Set 5 | santa flavia
# Processing Record 42 of Set 5 | san cristobal
# Processing Record 43 of Set 5 | lasa
# Processing Record 44 of Set 5 | touros
# Processing Record 45 of Set 5 | namatanai
# Processing Record 46 of Set 5 | half moon bay
# Processing Record 47 of Set 5 | mahebourg
# Processing Record 48 of Set 5 | tautira
# Processing Record 49 of Set 5 | kodino
# Processing Record 50 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 6 | astana
# Processing Record 2 of Set 6 | nanortalik
# Processing Record 3 of Set 6 | gabu
# Processing Record 4 of Set 6 | pangnirtung
# Processing Record 5 of Set 6 | fort nelson
# Processing Record 6 of Set 6 | tsienyane
# City not found. Skipping...
# Processing Record 7 of Set 6 | torbay
# Processing Record 8 of Set 6 | henderson
# Processing Record 9 of Set 6 | rietavas
# Processing Record 10 of Set 6 | kuala terengganu
# Processing Record 11 of Set 6 | pucallpa
# Processing Record 12 of Set 6 | hualmay
# Processing Record 13 of Set 6 | bethanien
# Processing Record 14 of Set 6 | aljezur
# Processing Record 15 of Set 6 | saint-augustin
# Processing Record 16 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 6 | cidreira
# Processing Record 18 of Set 6 | freeport
# Processing Record 19 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 6 | severo-kurilsk
# Processing Record 21 of Set 6 | ternate
# Processing Record 22 of Set 6 | hvammstangi
# City not found. Skipping...
# Processing Record 23 of Set 6 | shubarkuduk
# Processing Record 24 of Set 6 | nouadhibou
# Processing Record 25 of Set 6 | maniwaki
# Processing Record 26 of Set 6 | amapa
# Processing Record 27 of Set 6 | grindavik
# Processing Record 28 of Set 6 | isangel
# Processing Record 29 of Set 6 | tala
# Processing Record 30 of Set 6 | tasiilaq
# Processing Record 31 of Set 6 | vardo
# Processing Record 32 of Set 6 | qaqortoq
# Processing Record 33 of Set 6 | gushikawa
# Processing Record 34 of Set 6 | buncrana
# Processing Record 35 of Set 6 | kaduqli
# Processing Record 36 of Set 6 | faya
# Processing Record 37 of Set 6 | dongsheng
# Processing Record 38 of Set 6 | kiruna
# Processing Record 39 of Set 6 | santa maria
# Processing Record 40 of Set 6 | zavetnoye
# Processing Record 41 of Set 6 | hasaki
# Processing Record 42 of Set 6 | nanchang
# Processing Record 43 of Set 6 | ngorongoro
# Processing Record 44 of Set 6 | jalu
# Processing Record 45 of Set 6 | ushibuka
# Processing Record 46 of Set 6 | hithadhoo
# Processing Record 47 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 6 | san andres
# Processing Record 49 of Set 6 | narsaq
# Processing Record 50 of Set 6 | karratha
# Processing Record 1 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 7 | wagar
# Processing Record 3 of Set 7 | hirara
# Processing Record 4 of Set 7 | norman wells
# Processing Record 5 of Set 7 | ryotsu
# Processing Record 6 of Set 7 | lagoa
# Processing Record 7 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 8 of Set 7 | guaiba
# Processing Record 9 of Set 7 | makakilo city
# Processing Record 10 of Set 7 | luderitz
# Processing Record 11 of Set 7 | zhigansk
# Processing Record 12 of Set 7 | baykit
# Processing Record 13 of Set 7 | stoyba
# City not found. Skipping...
# Processing Record 14 of Set 7 | camacha
# Processing Record 15 of Set 7 | longyearbyen
# Processing Record 16 of Set 7 | sanghar
# Processing Record 17 of Set 7 | west odessa
# Processing Record 18 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 7 | loksa
# Processing Record 20 of Set 7 | nhulunbuy
# Processing Record 21 of Set 7 | san juan
# Processing Record 22 of Set 7 | koson
# Processing Record 23 of Set 7 | udachnyy
# Processing Record 24 of Set 7 | ardahan
# Processing Record 25 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 7 | bijie
# Processing Record 27 of Set 7 | alakurtti
# Processing Record 28 of Set 7 | kushmurun
# Processing Record 29 of Set 7 | santa cruz
# Processing Record 30 of Set 7 | sarangani
# Processing Record 31 of Set 7 | challans
# Processing Record 32 of Set 7 | tonj
# Processing Record 33 of Set 7 | pevek
# Processing Record 34 of Set 7 | geraldton
# Processing Record 35 of Set 7 | la baule-escoublac
# Processing Record 36 of Set 7 | ahipara
# Processing Record 37 of Set 7 | charters towers
# Processing Record 38 of Set 7 | hay river
# Processing Record 39 of Set 7 | pochutla
# Processing Record 40 of Set 7 | trairi
# Processing Record 41 of Set 7 | balabac
# Processing Record 42 of Set 7 | amudat
# Processing Record 43 of Set 7 | burica
# City not found. Skipping...
# Processing Record 44 of Set 7 | shetpe
# Processing Record 45 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 7 | acaponeta
# Processing Record 47 of Set 7 | islamkot
# Processing Record 48 of Set 7 | auki
# Processing Record 49 of Set 7 | bocas del toro
# Processing Record 50 of Set 7 | genthin
# Processing Record 1 of Set 8 | micheweni
# Processing Record 2 of Set 8 | esso
# Processing Record 3 of Set 8 | los llanos de aridane
# Processing Record 4 of Set 8 | saint-philippe
# Processing Record 5 of Set 8 | ruteng
# Processing Record 6 of Set 8 | basco
# Processing Record 7 of Set 8 | san jose de sisa
# Processing Record 8 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 8 | vanimo
# Processing Record 10 of Set 8 | palaikastron
# Processing Record 11 of Set 8 | yar-sale
# Processing Record 12 of Set 8 | kurbnesh
# Processing Record 13 of Set 8 | biak
# Processing Record 14 of Set 8 | kismayo
# Processing Record 15 of Set 8 | etchoropo
# Processing Record 16 of Set 8 | high level
# Processing Record 17 of Set 8 | bowen
# Processing Record 18 of Set 8 | yantai
# Processing Record 19 of Set 8 | makung
# City not found. Skipping...
# Processing Record 20 of Set 8 | araouane
# Processing Record 21 of Set 8 | gazli
# Processing Record 22 of Set 8 | broken hill
# Processing Record 23 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 8 | la asuncion
# Processing Record 25 of Set 8 | avera
# Processing Record 26 of Set 8 | mont-dore
# Processing Record 27 of Set 8 | saint anthony
# Processing Record 28 of Set 8 | anori
# Processing Record 29 of Set 8 | ucluelet
# Processing Record 30 of Set 8 | vung tau
# Processing Record 31 of Set 8 | lompoc
# Processing Record 32 of Set 8 | lakefield
# Processing Record 33 of Set 8 | jacmel
# Processing Record 34 of Set 8 | lavrentiya
# Processing Record 35 of Set 8 | aracati
# Processing Record 36 of Set 8 | linjiang
# Processing Record 37 of Set 8 | susanville
# Processing Record 38 of Set 8 | batagay-alyta
# Processing Record 39 of Set 8 | horsham
# Processing Record 40 of Set 8 | kavaratti
# Processing Record 41 of Set 8 | marsh harbour
# Processing Record 42 of Set 8 | la paz
# Processing Record 43 of Set 8 | sitka
# Processing Record 44 of Set 8 | touba
# Processing Record 45 of Set 8 | cherskiy
# Processing Record 46 of Set 8 | adrar
# Processing Record 47 of Set 8 | elda
# Processing Record 48 of Set 8 | pisco
# Processing Record 49 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 8 | ojinaga
# Processing Record 1 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 2 of Set 9 | korla
# Processing Record 3 of Set 9 | clyde river
# Processing Record 4 of Set 9 | lukovetskiy
# Processing Record 5 of Set 9 | zyryanka
# Processing Record 6 of Set 9 | oyama
# Processing Record 7 of Set 9 | cervo
# Processing Record 8 of Set 9 | berlevag
# Processing Record 9 of Set 9 | provins
# Processing Record 10 of Set 9 | masuguru
# Processing Record 11 of Set 9 | ngunguru
# Processing Record 12 of Set 9 | kloulklubed
# Processing Record 13 of Set 9 | haikou
# Processing Record 14 of Set 9 | katherine
# Processing Record 15 of Set 9 | alofi
# Processing Record 16 of Set 9 | ballina
# Processing Record 17 of Set 9 | pacific grove
# Processing Record 18 of Set 9 | huarmey
# Processing Record 19 of Set 9 | mayumba
# Processing Record 20 of Set 9 | kamaishi
# Processing Record 21 of Set 9 | cabedelo
# Processing Record 22 of Set 9 | manaure
# Processing Record 23 of Set 9 | koslan
# Processing Record 24 of Set 9 | kushima
# Processing Record 25 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 26 of Set 9 | sao felix do xingu
# Processing Record 27 of Set 9 | ganzhou
# Processing Record 28 of Set 9 | shimoda
# Processing Record 29 of Set 9 | gizo
# Processing Record 30 of Set 9 | kuldiga
# Processing Record 31 of Set 9 | mudu
# Processing Record 32 of Set 9 | caravelas
# Processing Record 33 of Set 9 | nioro
# Processing Record 34 of Set 9 | merauke
# Processing Record 35 of Set 9 | minsk
# Processing Record 36 of Set 9 | shumskiy
# Processing Record 37 of Set 9 | bakchar
# Processing Record 38 of Set 9 | airai
# Processing Record 39 of Set 9 | ullapool
# Processing Record 40 of Set 9 | almansa
# Processing Record 41 of Set 9 | libreville
# Processing Record 42 of Set 9 | kikwit
# Processing Record 43 of Set 9 | rusape
# Processing Record 44 of Set 9 | krasnoselkup
# Processing Record 45 of Set 9 | meadow lake
# Processing Record 46 of Set 9 | archidona
# Processing Record 47 of Set 9 | bintulu
# Processing Record 48 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 49 of Set 9 | doha
# Processing Record 50 of Set 9 | lazeshchyna
# Processing Record 1 of Set 10 | kichera
# Processing Record 2 of Set 10 | ambulu
# Processing Record 3 of Set 10 | guozhen
# Processing Record 4 of Set 10 | salalah
# Processing Record 5 of Set 10 | bezhetsk
# Processing Record 6 of Set 10 | fortuna
# Processing Record 7 of Set 10 | nuuk
# Processing Record 8 of Set 10 | bay city
# Processing Record 9 of Set 10 | myra
# Processing Record 10 of Set 10 | catuday
# Processing Record 11 of Set 10 | ylojarvi
# Processing Record 12 of Set 10 | sao joao do piaui
# Processing Record 13 of Set 10 | san quintin
# Processing Record 14 of Set 10 | nome
# Processing Record 15 of Set 10 | kashi
# Processing Record 16 of Set 10 | bayan
# Processing Record 17 of Set 10 | baisha
# Processing Record 18 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 10 | ust-kuyga
# Processing Record 20 of Set 10 | langholm
# Processing Record 21 of Set 10 | nangomba
# Processing Record 22 of Set 10 | mushie
# Processing Record 23 of Set 10 | caloundra
# Processing Record 24 of Set 10 | tabou
# Processing Record 25 of Set 10 | san isidro
# Processing Record 26 of Set 10 | semey
# Processing Record 27 of Set 10 | praya
# Processing Record 28 of Set 10 | honiara
# Processing Record 29 of Set 10 | sita road
# Processing Record 30 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 10 | shagamu
# Processing Record 32 of Set 10 | santa isabel do rio negro
# Processing Record 33 of Set 10 | meulaboh
# Processing Record 34 of Set 10 | ubeda
# Processing Record 35 of Set 10 | alexandria
# Processing Record 36 of Set 10 | yithion
# City not found. Skipping...
# Processing Record 37 of Set 10 | chechat
# Processing Record 38 of Set 10 | rawson
# Processing Record 39 of Set 10 | dondo
# Processing Record 40 of Set 10 | nagato
# Processing Record 41 of Set 10 | maniitsoq
# Processing Record 42 of Set 10 | sarankhola
# Processing Record 43 of Set 10 | sibolga
# Processing Record 44 of Set 10 | mundo nuevo
# Processing Record 45 of Set 10 | wilmington
# Processing Record 46 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 10 | marienburg
# Processing Record 48 of Set 10 | san-pedro
# Processing Record 49 of Set 10 | klichka
# Processing Record 50 of Set 10 | chokurdakh
# Processing Record 1 of Set 11 | kotaparh
# Processing Record 2 of Set 11 | saint-jean-de-braye
# Processing Record 3 of Set 11 | shaowu
# Processing Record 4 of Set 11 | taoudenni
# Processing Record 5 of Set 11 | innisfail
# Processing Record 6 of Set 11 | naze
# Processing Record 7 of Set 11 | otaki
# Processing Record 8 of Set 11 | ahumada
# City not found. Skipping...
# Processing Record 9 of Set 11 | tupik
# Processing Record 10 of Set 11 | sao paulo de olivenca
# Processing Record 11 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 11 | altamira
# Processing Record 13 of Set 11 | dunedin
# Processing Record 14 of Set 11 | canico
# Processing Record 15 of Set 11 | pandan
# Processing Record 16 of Set 11 | palmer
# Processing Record 17 of Set 11 | manokwari
# Processing Record 18 of Set 11 | gat
# Processing Record 19 of Set 11 | lebu
# Processing Record 20 of Set 11 | trofors
# Processing Record 21 of Set 11 | lalomanu
# City not found. Skipping...
# Processing Record 22 of Set 11 | vila franca do campo
# Processing Record 23 of Set 11 | drovyanaya
# Processing Record 24 of Set 11 | storforshei
# Processing Record 25 of Set 11 | khovu-aksy
# Processing Record 26 of Set 11 | manitouwadge
# Processing Record 27 of Set 11 | silvia
# Processing Record 28 of Set 11 | pemba
# Processing Record 29 of Set 11 | antalaha
# Processing Record 30 of Set 11 | bustamante
# Processing Record 31 of Set 11 | nueva imperial
# Processing Record 32 of Set 11 | castro
# Processing Record 33 of Set 11 | martapura
# Processing Record 34 of Set 11 | thiruvananthapuram
# Processing Record 35 of Set 11 | oksfjord
# Processing Record 36 of Set 11 | khawhai
# Processing Record 37 of Set 11 | liberia
# Processing Record 38 of Set 11 | hanzhong
# Processing Record 39 of Set 11 | sistranda
# Processing Record 40 of Set 11 | najran
# Processing Record 41 of Set 11 | marsa matruh
# Processing Record 42 of Set 11 | sayyan
# Processing Record 43 of Set 11 | asayita
# City not found. Skipping...
# Processing Record 44 of Set 11 | minab
# Processing Record 45 of Set 11 | acari
# Processing Record 46 of Set 11 | ayer itam
# City not found. Skipping...
# Processing Record 47 of Set 11 | bereda
# Processing Record 48 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 49 of Set 11 | labuan
# Processing Record 50 of Set 11 | pemangkat
# Processing Record 1 of Set 12 | ailigandi
# Processing Record 2 of Set 12 | buchanan
# Processing Record 3 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 4 of Set 12 | vestmannaeyjar
# Processing Record 5 of Set 12 | egvekinot
# Processing Record 6 of Set 12 | faanui
# Processing Record 7 of Set 12 | balykshi
# Processing Record 8 of Set 12 | flin flon
# Processing Record 9 of Set 12 | vetluga
# Processing Record 10 of Set 12 | vizinga
# Processing Record 11 of Set 12 | loralai
# Processing Record 12 of Set 12 | gwembe
# Processing Record 13 of Set 12 | briancon
# Processing Record 14 of Set 12 | horizontina
# Processing Record 15 of Set 12 | alta floresta
# Processing Record 16 of Set 12 | cesvaine
# Processing Record 17 of Set 12 | hambantota
# Processing Record 18 of Set 12 | synya
# Processing Record 19 of Set 12 | strezhevoy
# Processing Record 20 of Set 12 | tirumullaivasal
# Processing Record 21 of Set 12 | karangampel
# Processing Record 22 of Set 12 | harper
# Processing Record 23 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 24 of Set 12 | camana
# Processing Record 25 of Set 12 | thung song
# Processing Record 26 of Set 12 | inta
# Processing Record 27 of Set 12 | macaboboni
# City not found. Skipping...
# Processing Record 28 of Set 12 | bundaberg
# Processing Record 29 of Set 12 | largo
# Processing Record 30 of Set 12 | tuatapere
# Processing Record 31 of Set 12 | anacortes
# Processing Record 32 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 33 of Set 12 | rabo de peixe
# Processing Record 34 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 35 of Set 12 | constitucion
# Processing Record 36 of Set 12 | bondoukou
# Processing Record 37 of Set 12 | nueva gerona
# Processing Record 38 of Set 12 | jining
# Processing Record 39 of Set 12 | arman
# Processing Record 40 of Set 12 | garhi khairo
# Processing Record 41 of Set 12 | raga
# Processing Record 42 of Set 12 | san pedro
# Processing Record 43 of Set 12 | hereford
# Processing Record 44 of Set 12 | itororo
# Processing Record 45 of Set 12 | eganville
# Processing Record 46 of Set 12 | paamiut
# Processing Record 47 of Set 12 | pointe michel
# Processing Record 48 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 12 | pedernales
# Processing Record 50 of Set 12 | manggar
# Processing Record 1 of Set 13 | trondheim
# Processing Record 2 of Set 13 | yichang
# Processing Record 3 of Set 13 | port blair
# Processing Record 4 of Set 13 | leningradskiy
# Processing Record 5 of Set 13 | tezu
# Processing Record 6 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 7 of Set 13 | banamba
# Processing Record 8 of Set 13 | digha
# Processing Record 9 of Set 13 | grenfell
# Processing Record 10 of Set 13 | dingle
# Processing Record 11 of Set 13 | kabare
# Processing Record 12 of Set 13 | daru
# Processing Record 13 of Set 13 | sabang
# Processing Record 14 of Set 13 | tiznit
# Processing Record 15 of Set 13 | mpulungu
# Processing Record 16 of Set 13 | hailar
# Processing Record 17 of Set 13 | ixmiquilpan
# Processing Record 18 of Set 13 | marawi
# Processing Record 19 of Set 13 | khandbari
# Processing Record 20 of Set 13 | banda aceh
# Processing Record 21 of Set 13 | racale
# Processing Record 22 of Set 13 | saint-georges
# Processing Record 23 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 24 of Set 13 | kawalu
# Processing Record 25 of Set 13 | guliston
# Processing Record 26 of Set 13 | istok
# Processing Record 27 of Set 13 | tsaratanana
# Processing Record 28 of Set 13 | tomatlan
# Processing Record 29 of Set 13 | bad neustadt
# City not found. Skipping...
# Processing Record 30 of Set 13 | newport
# Processing Record 31 of Set 13 | big bend
# Processing Record 32 of Set 13 | dargaville
# Processing Record 33 of Set 13 | ambilobe
# Processing Record 34 of Set 13 | izumo
# Processing Record 35 of Set 13 | kirkwall
# Processing Record 36 of Set 13 | port-gentil
# Processing Record 37 of Set 13 | urucara
# Processing Record 38 of Set 13 | valleyview
# Processing Record 39 of Set 13 | nanakuli
# Processing Record 40 of Set 13 | solnechnyy
# Processing Record 41 of Set 13 | mezen
# Processing Record 42 of Set 13 | aswan
# Processing Record 43 of Set 13 | batagay
# Processing Record 44 of Set 13 | staryy nadym
# Processing Record 45 of Set 13 | bondo
# Processing Record 46 of Set 13 | langsa
# Processing Record 47 of Set 13 | at-bashi
# Processing Record 48 of Set 13 | maumere
# Processing Record 49 of Set 13 | humaita
# Processing Record 50 of Set 13 | pierre
# Processing Record 1 of Set 14 | bairiki
# Processing Record 2 of Set 14 | cururupu
# Processing Record 3 of Set 14 | port-cartier
# Processing Record 4 of Set 14 | praia da vitoria
# Processing Record 5 of Set 14 | malinyi
# Processing Record 6 of Set 14 | olafsvik
# Processing Record 7 of Set 14 | rantepao
# Processing Record 8 of Set 14 | jibuti
# Processing Record 9 of Set 14 | ust-nera
# Processing Record 10 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 14 | ranong
# Processing Record 12 of Set 14 | ust-tsilma
# Processing Record 13 of Set 14 | iza
# Processing Record 14 of Set 14 | toora-khem
# Processing Record 15 of Set 14 | lhokseumawe
# Processing Record 16 of Set 14 | tura
# Processing Record 17 of Set 14 | wellington
# Processing Record 18 of Set 14 | turtkul
# City not found. Skipping...
# Processing Record 19 of Set 14 | mukhen
# Processing Record 20 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 21 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 22 of Set 14 | krasnokamensk
# Processing Record 23 of Set 14 | camopi
# Processing Record 24 of Set 14 | bonavista
# Processing Record 25 of Set 14 | srednekolymsk
# Processing Record 26 of Set 14 | khandyga
# Processing Record 27 of Set 14 | pedro betancourt
# Processing Record 28 of Set 14 | puro
# Processing Record 29 of Set 14 | brownsville
# Processing Record 30 of Set 14 | bodden town
# Processing Record 31 of Set 14 | ostersund
# Processing Record 32 of Set 14 | gerash
# Processing Record 33 of Set 14 | nicoya
# Processing Record 34 of Set 14 | shurugwi
# Processing Record 35 of Set 14 | neryungri
# Processing Record 36 of Set 14 | sobolevo
# Processing Record 37 of Set 14 | belyy yar
# Processing Record 38 of Set 14 | tighina
# Processing Record 39 of Set 14 | atikokan
# Processing Record 40 of Set 14 | rocha
# Processing Record 41 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 42 of Set 14 | tukrah
# Processing Record 43 of Set 14 | kirkuk
# Processing Record 44 of Set 14 | ornskoldsvik
# Processing Record 45 of Set 14 | rio brilhante
# Processing Record 46 of Set 14 | lida
# Processing Record 47 of Set 14 | ferme-neuve
# Processing Record 48 of Set 14 | puerto del rosario
# Processing Record 49 of Set 14 | nagapattinam
# Processing Record 50 of Set 14 | kosh-agach
# Processing Record 1 of Set 15 | komsomolskiy
# Processing Record 2 of Set 15 | ajaccio
# Processing Record 3 of Set 15 | batemans bay
# Processing Record 4 of Set 15 | shelburne
# Processing Record 5 of Set 15 | sidi ali
# Processing Record 6 of Set 15 | aldergrove
# Processing Record 7 of Set 15 | kemijarvi
# Processing Record 8 of Set 15 | kachiry
# Processing Record 9 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 15 | taltal
# Processing Record 11 of Set 15 | bud
# Processing Record 12 of Set 15 | sovetskiy
# Processing Record 13 of Set 15 | hami
# Processing Record 14 of Set 15 | ylivieska
# Processing Record 15 of Set 15 | la ronge
# Processing Record 16 of Set 15 | rwamagana
# Processing Record 17 of Set 15 | sabinas hidalgo
# Processing Record 18 of Set 15 | raudeberg
# Processing Record 19 of Set 15 | waingapu
# Processing Record 20 of Set 15 | nova vicosa
# Processing Record 21 of Set 15 | tyret pervaya
# Processing Record 22 of Set 15 | tepic
# Processing Record 23 of Set 15 | poronaysk
# Processing Record 24 of Set 15 | turukhansk
# Processing Record 25 of Set 15 | beira
# Processing Record 26 of Set 15 | kununurra
# Processing Record 27 of Set 15 | shingu
# Processing Record 28 of Set 15 | liverpool
# Processing Record 29 of Set 15 | esna
# Processing Record 30 of Set 15 | mogadishu
# Processing Record 31 of Set 15 | sao francisco de assis
# Processing Record 32 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 33 of Set 15 | ampanihy
# Processing Record 34 of Set 15 | tsiroanomandidy
# Processing Record 35 of Set 15 | scarborough
# Processing Record 36 of Set 15 | piterka
# Processing Record 37 of Set 15 | general roca
# Processing Record 38 of Set 15 | feijo
# Processing Record 39 of Set 15 | kiparissia
# City not found. Skipping...
# Processing Record 40 of Set 15 | vuktyl
# Processing Record 41 of Set 15 | dinsor
# City not found. Skipping...
# Processing Record 42 of Set 15 | raton
# Processing Record 43 of Set 15 | guarapari
# Processing Record 44 of Set 15 | marrakesh
# Processing Record 45 of Set 15 | kharp
# Processing Record 46 of Set 15 | tuy hoa
# Processing Record 47 of Set 15 | aleksandrov gay
# Processing Record 48 of Set 15 | visp
# Processing Record 49 of Set 15 | sabzevar
# Processing Record 50 of Set 15 | soyo
# Processing Record 1 of Set 16 | anadyr
# Processing Record 2 of Set 16 | villarrica
# Processing Record 3 of Set 16 | metro
# Processing Record 4 of Set 16 | tongzhou
# Processing Record 5 of Set 16 | luganville
# Processing Record 6 of Set 16 | kayerkan
# Processing Record 7 of Set 16 | my tho
# Processing Record 8 of Set 16 | seoul
# Processing Record 9 of Set 16 | north platte
# Processing Record 10 of Set 16 | shache
# Processing Record 11 of Set 16 | finschhafen
# Processing Record 12 of Set 16 | eureka
# Processing Record 13 of Set 16 | san rafael
# Processing Record 14 of Set 16 | bafoulabe
# Processing Record 15 of Set 16 | moree
# Processing Record 16 of Set 16 | mitrofanovka
# Processing Record 17 of Set 16 | san policarpo
# Processing Record 18 of Set 16 | kozhevnikovo
# Processing Record 19 of Set 16 | solsvik
# City not found. Skipping...
# Processing Record 20 of Set 16 | jolalpan
# Processing Record 21 of Set 16 | limbazi
# Processing Record 22 of Set 16 | olinda
# Processing Record 23 of Set 16 | mamlyutka
# Processing Record 24 of Set 16 | nantucket
# Processing Record 25 of Set 16 | banepa
# Processing Record 26 of Set 16 | falam
# Processing Record 27 of Set 16 | sento se
# City not found. Skipping...
# Processing Record 28 of Set 16 | fatehabad
# Processing Record 29 of Set 16 | imbituba
# Processing Record 30 of Set 16 | litovko
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Adding data to a new dataframe

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Port Alfred      ZA -33.5906   26.8910     61.54        64          12
# 1             Hilo      US  19.7297 -155.0900     76.28        92          90
# 2          Aklavik      CA  68.2191 -135.0107     28.47        83         100
# 3          College      US  64.8569 -147.8028     35.26        94          75
# 4           Tarata      BO -17.6167  -66.0167     85.42        29          46
# 5  Arraial Do Cabo      BR -22.9661  -42.0278     67.96        94          90
# 6      Yellowknife      CA  62.4560 -114.3525     38.41        99         100
# 7     Punta Arenas      CL -53.1500  -70.9167     53.71        35          20
# 8   Ribeira Grande      PT  38.5167  -28.7000     72.00        94          75
# 9          Sarandi      BR -23.4436  -51.8739     65.17        83         100
#
#    Wind Speed      Current Description
# 0       20.69               few clouds
# 1        5.75               light rain
# 2        9.93          overcast clouds
# 3        6.91                      fog
# 4        9.13         scattered clouds
# 5       12.66  light intensity drizzle
# 6       13.00          overcast clouds
# 7       31.07               few clouds
# 8       12.66            broken clouds
# 9       11.52          overcast clouds

# %%
# Create the output file.
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
